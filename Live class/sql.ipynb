# %%
#Driver

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host= 'localhost', user = 'root', password = 'mysql')

# %%
cursor = mydb.cursor()

# %%
cursor.execute('show databases')

# %%
cursor.fetchall()
# Out:
# [('customer',),
#  ('glassdata',),
#  ('grocery_store',),
#  ('imdb',),
#  ('ineuron',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('student',),
#  ('sys',),
#  ('testsudhineuron',),
#  ('testsudhineuron1',),
#  ('world',)]

# %%
'''#Create own database
1. Est a communication through connection variable
2. Cursor is imp:- cursor = mydb.cursor()
3. execute
4. Fetchall'''
# Out:
# '#Create own database\n1. Est a communication through connection variable\n2. Cursor is imp:- cursor = mydb.cursor()\n3. execute\n4. Fetchall'

# %%
cursor = mydb.cursor()

# %%
cursor.execute("create database testsudhineuron1")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Desktop\Anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                 query = query.encode('utf-8')
# --> 516             self._cmysql.query(query,
#     517                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Can't create database 'testsudhineuron1'; database exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-10-456ec903408b> in <module>
# ----> 1 cursor.execute("create database testsudhineuron1")
#
# ~\Desktop\Anaconda\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     267
#     268         try:
# ...

# %%
#Create table inside that database

# %%
cursor.execute("create table testsudhineuron1.ineuron(studentid INT(10), firstname VARCHAR(30), lastname VARCHAR(30), regid INT(10), classname VARCHAR(30))")

#"Create table dbname.tablename"
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Desktop\Anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                 query = query.encode('utf-8')
# --> 516             self._cmysql.query(query,
#     517                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'ineuron' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-11-9eeed416382f> in <module>
# ----> 1 cursor.execute("create table testsudhineuron1.ineuron(studentid INT(10), firstname VARCHAR(30), lastname VARCHAR(30), regid INT(10), classname VARCHAR(30))")
#       2
#       3 #"Create table dbname.tablename"
#
# ...

# %%
cursor.execute('use testsudhineuron1')  #use databasename

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
#Insert entries

# %%
cursor.execute("insert into testsudhineuron1.ineuron values(7688, 'eudh', 'eumar', 658787, 'fsds')")

#"Insert into dbname.tablename values"

# %%
mydb.commit()

# %%
cursor.execute("select * from testsudhineuron1.ineuron")

# %%
cursor.fetchall()
# Out:
# [(7688, 'eudh', 'eumar', 658787, 'fsds'),
#  (7688, 'eudh', 'eumar', 658787, 'fsds')]

# %%
#insert bulk data inside a db
#1. Create a table

# %%
cursor.execute('create table testsudhineuron1.glassdata(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 int(10))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Desktop\Anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                 query = query.encode('utf-8')
# --> 516             self._cmysql.query(query,
#     517                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'glassdata' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-15-0f9e1f2b8356> in <module>
# ----> 1 cursor.execute('create table testsudhineuron1.glassdata(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 int(10))')
#
# ...

# %%
mydb.commit()

# %%
cursor.execute('use testsudhineuron')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('ineuron',)]

# %%
ls
# Out:
#  Volume in drive C is WINDOWS
#  Volume Serial Number is 4816-94F1
#
#  Directory of C:\Users\Lakshya\DS_Python\Live class
#
# 02/05/2022  11:47 AM    <DIR>          .
# 02/05/2022  11:47 AM    <DIR>          ..
# 02/05/2022  10:25 AM    <DIR>          .ipynb_checkpoints
# 01/22/2022  11:06 AM    <DIR>          __pycache__
# 02/03/2022  03:55 PM                 0 fightstory.txt
# 01/14/2022  03:47 PM               487 google.txt
# 02/04/2022  11:49 PM            30,809 Jan 15 & 16.ipynb
# 01/23/2022  12:43 PM            23,704 Jan 23.ipynb
# 01/30/2022  12:24 PM            18,952 Jan 30.ipynb
# 01/22/2022  01:00 PM            20,591 Jan22.ipynb
# 01/29/2022  12:34 PM            20,735 Jan29.ipynb
# 12/21/2021  10:10 PM            18,542 Live class day 5.ipynb
# 12/22/2021  12:57 PM            12,767 Live class day1.ipynb
# 12/22/2021  02:52 PM            49,095 live class day2.ipynb
# 01/08/2022  02:25 AM            15,664 live class day3.ipynb
# ...

# %%
file = open(r'C:\Users\Lakshya\DS_Python\glass.data', 'r')

# %%
file.read()
# Out:
# 'index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class\n1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.3
# ...

# %%
#We can use delimitr option to show the data row wise

# %%
import csv   
with open(r'C:\Users\Lakshya\DS_Python\glass.data', 'r') as f:  #Read all the data
    glass_data = csv.reader(f, delimiter = '\n') #file wll be read in csv thats why i have imported csv package above
    for i in glass_data:
        print(i)
# Out:
# ['index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class']
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ...

# %%
#To insert a data inside a particular table

# %%
cursor.execute('create table testsudhineuron1.glassdata(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 int(10))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Desktop\Anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                 query = query.encode('utf-8')
# --> 516             self._cmysql.query(query,
#     517                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'glassdata' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-20-0f9e1f2b8356> in <module>
# ----> 1 cursor.execute('create table testsudhineuron1.glassdata(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 int(10))')
#
# ...

# %%
cursor.execute('insert into testsudhineuron1.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)')

# %%
 mydb.commit()

# %%
cursor.execute("select * from testsudhineuron1.glassdata")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1)]

# %%
with open(r"C:\Users\Lakshya\DS_Python\glass.data", 'r') as f:
    glass_data = csv.reader(f, delimiter='\n')
    for i in glass_data:
        print(type(i[0]))
        print(f'insert into glassdata1 values ({str(i[0])})')
        cursor.execute('insert into testsuhineuron1.glassdata1 values({values})'.format(values = ((i[0]))))
# Out:
# <class 'str'>
# insert into glassdata1 values (index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class)
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Desktop\Anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     515                 query = query.encode('utf-8')
# --> 516             self._cmysql.query(query,
#     517                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'index,RI,Na,Mg,Al,Si,K,Ca,Ba,Fe,Class)' at line 1
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-14-e1b2c0c6c3ad> in <module>
#       4         print(type(i[0]))
# ...

# %%
import pandas as pd

# %%
pd.read_sql("select * from testsudhineuron1.glassdata", mydb)
# Out:
#    col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0     1  1.52101  13.64  4.49   1.1  71.78  0.06  8.75   0.0    0.0      1
# 1     1  1.52101  13.64  4.49   1.1  71.78  0.06  8.75   0.0    0.0      1

# %%
pd.read_sql("show databases", mydb)
# Out:
#               Database
# 0             customer
# 1            glassdata
# 2        grocery_store
# 3                 imdb
# 4              ineuron
# 5   information_schema
# 6                mysql
# 7   performance_schema
# 8               sakila
# 9              student
# 10                 sys
# 11     testsudhineuron
# 12    testsudhineuron1
# 13               world

# %%
pd.read_sql("use testsudhineuron1", mydb)

#We are not fetching something here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-daca08f57e5c> in <module>
# ----> 1 pd.read_sql("use testsudhineuron1", mydb)
#
# ~\Desktop\Anaconda\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# ~\Desktop\Anaconda\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1770         args = _convert_params(sql, params)
#    1771         cursor = self.execute(*args)
# -> 1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#    1774         if chunksize is not None:
#
# ...
