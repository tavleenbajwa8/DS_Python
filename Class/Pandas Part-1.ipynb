# %%
import pandas as pd

# %%
#Reading operation in Pandas

# %%
pd = pd.read_csv(r"C:\Users\Lakshya\Downloads\student.csv")

# %%
#To know total number of records

# %%
pd
# Out:
#       id    name         dob sex class hcode dcode  mtest
# 0   1001     ABA   11/5/1986   M    1A     B   TST     84
# 1   1002    Mary  25-06-1986   F    2B     B    YL     82
# 2   1003   David  17-03-1988   M    1A     G    TM     84
# 3   1004    John  17-01-1985   M    1C     B    YL     82
# 4   1005     May  15-11-1986   F    1A     B    TP     30
# 5   1006   Janet    4/6/1986   F    2B     R   TST     62
# 6   1007   Steve  31-03-1987   M    2C     R    TM     38
# 7   1008   Chris   12/1/1984   M    1A     B    YL     49
# 8   1009  Robert    3/9/1987   M    1A     G   TST     63
# 9   1010    June  15-02-1988   F    1B     R   YMT     59
# 10  1011   Judie  23-02-1986   F    2C     R   TST     62
# 11  1012   Sally    5/7/1986   F    3A     G    YL     71
# 12  1013   Sammi  14-08-1986   F    1B     B    TM     84
# 13  1014   katie  22-09-1986   F    1C     B   YMT     42
# 14  1015  Wilson  12/10/1986   M    1A     R    YL     66
# ...

# %%
pd.head()  #Show 1st 5 records by default
# Out:
#      id   name         dob sex class hcode dcode  mtest
# 0  1001    ABA   11/5/1986   M    1A     B   TST     84
# 1  1002   Mary  25-06-1986   F    2B     B    YL     82
# 2  1003  David  17-03-1988   M    1A     G    TM     84
# 3  1004   John  17-01-1985   M    1C     B    YL     82
# 4  1005    May  15-11-1986   F    1A     B    TP     30

# %%
pd.head(2)
# Out:
#      id  name         dob sex class hcode dcode  mtest
# 0  1001   ABA   11/5/1986   M    1A     B   TST     84
# 1  1002  Mary  25-06-1986   F    2B     B    YL     82

# %%
pd.head(13)
# Out:
#       id    name         dob sex class hcode dcode  mtest
# 0   1001     ABA   11/5/1986   M    1A     B   TST     84
# 1   1002    Mary  25-06-1986   F    2B     B    YL     82
# 2   1003   David  17-03-1988   M    1A     G    TM     84
# 3   1004    John  17-01-1985   M    1C     B    YL     82
# 4   1005     May  15-11-1986   F    1A     B    TP     30
# 5   1006   Janet    4/6/1986   F    2B     R   TST     62
# 6   1007   Steve  31-03-1987   M    2C     R    TM     38
# 7   1008   Chris   12/1/1984   M    1A     B    YL     49
# 8   1009  Robert    3/9/1987   M    1A     G   TST     63
# 9   1010    June  15-02-1988   F    1B     R   YMT     59
# 10  1011   Judie  23-02-1986   F    2C     R   TST     62
# 11  1012   Sally    5/7/1986   F    3A     G    YL     71
# 12  1013   Sammi  14-08-1986   F    1B     B    TM     84

# %%
pd.tail()
# Out:
#       id    name         dob sex class hcode dcode  mtest
# 12  1013   Sammi  14-08-1986   F    1B     B    TM     84
# 13  1014   katie  22-09-1986   F    1C     B   YMT     42
# 14  1015  Wilson  12/10/1986   M    1A     R    YL     66
# 15  1016   Tommy   5/12/1986   M    1A     G    TM     33
# 16  1017    Till  14-04-1986   M    2B     R    TP     81

# %%
#Dataframe(Storing data in datafrae format) = Tabular structure form of data

# %%
df = pd.read_csv(r"C:\Users\Lakshya\Downloads\student.csv")

# %%
type(df)   #Internally trying to convert whole dataset into a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df.head()

# %%
df.tail()
# Out:
#       id    name         dob sex class hcode dcode  mtest
# 12  1013   Sammi  14-08-1986   F    1B     B    TM     84
# 13  1014   katie  22-09-1986   F    1C     B   YMT     42
# 14  1015  Wilson  12/10/1986   M    1A     R    YL     66
# 15  1016   Tommy   5/12/1986   M    1A     G    TM     33
# 16  1017    Till  14-04-1986   M    2B     R    TP     81

# %%
#To store data into a csv format

# %%
df1.to_csv("test.csv")

# %%
pwd()
# Out:
# 'C:\\Users\\Lakshya\\DS_Python'

# %%
# !dir
# Out:
#  Volume in drive C is WINDOWS
#  Volume Serial Number is 4816-94F1
#
#  Directory of C:\Users\Lakshya\DS_Python
#
# 01/03/2022  12:53 PM    <DIR>          .
# 01/03/2022  12:53 PM    <DIR>          ..
# 01/03/2022  11:57 AM    <DIR>          .ipynb_checkpoints
# 12/01/2021  12:44 AM            10,576 19.2.MySQL-checkpoint.ipynb
# 12/01/2021  12:36 AM         7,290,387 19.2.MySQL.7z
# 11/27/2021  10:22 PM            11,821 Abstraction, Inheritance, Encapsulation.ipynb
# 11/16/2021  07:25 PM                79 addition.py
# 12/19/2021  10:29 PM    <DIR>          Assignments
# 10/31/2021  12:30 PM       252,321,469 DS_FunctionClass2.ipynb
# 10/26/2021  04:09 PM            35,601 DS_Functions(1st class).ipynb
# 10/14/2021  01:36 AM             8,503 DS_List.ipynb
# 10/31/2021  09:08 AM             5,687 DS_PythonBasics.ipynb
# 10/21/2021  01:06 PM            75,869 DS_String_and_list_manipulation.ipynb
# 10/24/2021  09:26 AM            86,489 DS_Tuple_Set_Dictionaries.ipynb
# ...

# %%
pd.read_csv('test.csv')  #Adds 1 new column named 'unnamed'
# Out:
#    Unnamed: 0    id   name         dob sex class hcode dcode  mtest
# 0           0  1001    ABA   11/5/1986   M    1A     B   TST     84
# 1           1  1002   Mary  25-06-1986   F    2B     B    YL     82
# 2           2  1003  David  17-03-1988   M    1A     G    TM     84
# 3           3  1004   John  17-01-1985   M    1C     B    YL     82
# 4           4  1005    May  15-11-1986   F    1A     B    TP     30

# %%
#Seperator by default is a comma but it can be anything like #,$ etc

df = pd.read_csv (r"C:\Users\Lakshya\Downloads\student.csv", sep='#')

# %%
df  #Comma(delimiter) has been changed
# Out:
#       id    name         dob sex class hcode dcode  mtest
# 0   1001     ABA   11/5/1986   M    1A     B   TST     84
# 1   1002    Mary  25-06-1986   F    2B     B    YL     82
# 2   1003   David  17-03-1988   M    1A     G    TM     84
# 3   1004    John  17-01-1985   M    1C     B    YL     82
# 4   1005     May  15-11-1986   F    1A     B    TP     30
# 5   1006   Janet    4/6/1986   F    2B     R   TST     62
# 6   1007   Steve  31-03-1987   M    2C     R    TM     38
# 7   1008   Chris   12/1/1984   M    1A     B    YL     49
# 8   1009  Robert    3/9/1987   M    1A     G   TST     63
# 9   1010    June  15-02-1988   F    1B     R   YMT     59
# 10  1011   Judie  23-02-1986   F    2C     R   TST     62
# 11  1012   Sally    5/7/1986   F    3A     G    YL     71
# 12  1013   Sammi  14-08-1986   F    1B     B    TM     84
# 13  1014   katie  22-09-1986   F    1C     B   YMT     42
# 14  1015  Wilson  12/10/1986   M    1A     R    YL     66
# ...

# %%
#Header earlier was infer by default(very 1st record) id,name,dob etc, when we make it none it gives column indexes by default.

df = pd.read_csv (r"C:\Users\Lakshya\Downloads\student.csv", sep='#', header=None)

# %%
df
# Out:
#        0       1           2    3      4      5      6      7
# 0     id    name         dob  sex  class  hcode  dcode  mtest
# 1   1001     ABA   11/5/1986    M     1A      B    TST     84
# 2   1002    Mary  25-06-1986    F     2B      B     YL     82
# 3   1003   David  17-03-1988    M     1A      G     TM     84
# 4   1004    John  17-01-1985    M     1C      B     YL     82
# 5   1005     May  15-11-1986    F     1A      B     TP     30
# 6   1006   Janet    4/6/1986    F     2B      R    TST     62
# 7   1007   Steve  31-03-1987    M     2C      R     TM     38
# 8   1008   Chris   12/1/1984    M     1A      B     YL     49
# 9   1009  Robert    3/9/1987    M     1A      G    TST     63
# 10  1010    June  15-02-1988    F     1B      R    YMT     59
# 11  1011   Judie  23-02-1986    F     2C      R    TST     62
# 12  1012   Sally    5/7/1986    F     3A      G     YL     71
# 13  1013   Sammi  14-08-1986    F     1B      B     TM     84
# ...

# %%
#We can give names of our choice to columns. 

df = pd.read_csv (r"C:\Users\Lakshya\Downloads\student.csv", sep='#', header=None,names=['a','b','c','d','e','f','g'])

# %%
df
# Out:
#            a           b    c      d      e      f      g
# id      name         dob  sex  class  hcode  dcode  mtest
# 1001     ABA   11/5/1986    M     1A      B    TST     84
# 1002    Mary  25-06-1986    F     2B      B     YL     82
# 1003   David  17-03-1988    M     1A      G     TM     84
# 1004    John  17-01-1985    M     1C      B     YL     82
# 1005     May  15-11-1986    F     1A      B     TP     30
# 1006   Janet    4/6/1986    F     2B      R    TST     62
# 1007   Steve  31-03-1987    M     2C      R     TM     38
# 1008   Chris   12/1/1984    M     1A      B     YL     49
# 1009  Robert    3/9/1987    M     1A      G    TST     63
# 1010    June  15-02-1988    F     1B      R    YMT     59
# 1011   Judie  23-02-1986    F     2C      R    TST     62
# 1012   Sally    5/7/1986    F     3A      G     YL     71
# 1013   Sammi  14-08-1986    F     1B      B     TM     84
# 1014   katie  22-09-1986    F     1C      B    YMT     42
# ...

# %%
#To remove/skip any row, we can use 'skiprows', the rows will be removed but indexes will not change, they will update itself.

df = pd.read_csv (r"C:\Users\Lakshya\Downloads\student.csv", sep='#', header=None, skiprows=[0,4,6])

# %%
df
# Out:
#        0       1           2  3   4  5    6   7
# 0   1001     ABA   11/5/1986  M  1A  B  TST  84
# 1   1002    Mary  25-06-1986  F  2B  B   YL  82
# 2   1003   David  17-03-1988  M  1A  G   TM  84
# 3   1005     May  15-11-1986  F  1A  B   TP  30
# 4   1007   Steve  31-03-1987  M  2C  R   TM  38
# 5   1008   Chris   12/1/1984  M  1A  B   YL  49
# 6   1009  Robert    3/9/1987  M  1A  G  TST  63
# 7   1010    June  15-02-1988  F  1B  R  YMT  59
# 8   1011   Judie  23-02-1986  F  2C  R  TST  62
# 9   1012   Sally    5/7/1986  F  3A  G   YL  71
# 10  1013   Sammi  14-08-1986  F  1B  B   TM  84
# 11  1014   katie  22-09-1986  F  1C  B  YMT  42
# 12  1015  Wilson  12/10/1986  M  1A  R   YL  66
# 13  1016   Tommy   5/12/1986  M  1A  G   TM  33
# 14  1017    Till  14-04-1986  M  2B  R   TP  81

# %%
df = pd.read_csv(r"C:\Users\Lakshya\Downloads\student.csv", sep='#', header=None, skiprows=[0,4,6])

# %%
#na_values will consider that particular value as null

df = pd.read_csv (r"C:\Users\Lakshya\Downloads\student.csv",sep='#',na_values=['M'])

# %%
df
# Out:
#       id    name         dob  sex class hcode dcode  mtest
# 0   1001     ABA   11/5/1986  NaN    1A     B   TST     84
# 1   1002    Mary  25-06-1986    F    2B     B    YL     82
# 2   1003   David  17-03-1988  NaN    1A     G    TM     84
# 3   1004    John  17-01-1985  NaN    1C     B    YL     82
# 4   1005     May  15-11-1986    F    1A     B    TP     30
# 5   1006   Janet    4/6/1986    F    2B     R   TST     62
# 6   1007   Steve  31-03-1987  NaN    2C     R    TM     38
# 7   1008   Chris   12/1/1984  NaN    1A     B    YL     49
# 8   1009  Robert    3/9/1987  NaN    1A     G   TST     63
# 9   1010    June  15-02-1988    F    1B     R   YMT     59
# 10  1011   Judie  23-02-1986    F    2C     R   TST     62
# 11  1012   Sally    5/7/1986    F    3A     G    YL     71
# 12  1013   Sammi  14-08-1986    F    1B     B    TM     84
# 13  1014   katie  22-09-1986    F    1C     B   YMT     42
# 14  1015  Wilson  12/10/1986  NaN    1A     R    YL     66
# ...

# %%
df = pd.read_csv (r"C:\Users\Lakshya\Downloads\student.csv",sep='#', header=None,na_values=['ABA',63])

# %%
df
# Out:
#        0       1           2    3      4      5      6      7
# 0     id    name         dob  sex  class  hcode  dcode  mtest
# 1   1001     NaN   11/5/1986    M     1A      B    TST     84
# 2   1002    Mary  25-06-1986    F     2B      B     YL     82
# 3   1003   David  17-03-1988    M     1A      G     TM     84
# 4   1004    John  17-01-1985    M     1C      B     YL     82
# 5   1005     May  15-11-1986    F     1A      B     TP     30
# 6   1006   Janet    4/6/1986    F     2B      R    TST     62
# 7   1007   Steve  31-03-1987    M     2C      R     TM     38
# 8   1008   Chris   12/1/1984    M     1A      B     YL     49
# 9   1009  Robert    3/9/1987    M     1A      G    TST    NaN
# 10  1010    June  15-02-1988    F     1B      R    YMT     59
# 11  1011   Judie  23-02-1986    F     2C      R    TST     62
# 12  1012   Sally    5/7/1986    F     3A      G     YL     71
# 13  1013   Sammi  14-08-1986    F     1B      B     TM     84
# ...

# %%
df = pd.read_csv (r"C:\Users\Lakshya\Downloads\student.csv",sep='#',header=None,skiprows=[0,1,2])

# %%
df
# Out:
#        0       1           2  3   4  5    6   7
# 0   1003   David  17-03-1988  M  1A  G   TM  84
# 1   1004    John  17-01-1985  M  1C  B   YL  82
# 2   1005     May  15-11-1986  F  1A  B   TP  30
# 3   1006   Janet    4/6/1986  F  2B  R  TST  62
# 4   1007   Steve  31-03-1987  M  2C  R   TM  38
# 5   1008   Chris   12/1/1984  M  1A  B   YL  49
# 6   1009  Robert    3/9/1987  M  1A  G  TST  63
# 7   1010    June  15-02-1988  F  1B  R  YMT  59
# 8   1011   Judie  23-02-1986  F  2C  R  TST  62
# 9   1012   Sally    5/7/1986  F  3A  G   YL  71
# 10  1013   Sammi  14-08-1986  F  1B  B   TM  84
# 11  1014   katie  22-09-1986  F  1C  B  YMT  42
# 12  1015  Wilson  12/10/1986  M  1A  R   YL  66
# 13  1016   Tommy   5/12/1986  M  1A  G   TM  33
# 14  1017    Till  14-04-1986  M  2B  R   TP  81

# %%
 df.describe()
    
#Describe giving only 2 columns which have numerical data by default. 
#But we will be able to get categorical info

#Count: Total no. of values inside that column. If some column has different count then it means we have NaN values in that column.To reconfirm we can tally it with no of records, to know which column has null values.
#mean: Summation of all data/total no of data.
#std: Fluctuation from mean(mean+-std)
#rest values are calculated post sorting (min to max)
# Out:
#                  0          7
# count    15.000000  15.000000
# mean   1010.000000  60.400000
# std       4.472136  18.531055
# min    1003.000000  30.000000
# 25%    1006.500000  45.500000
# 50%    1010.000000  62.000000
# 75%    1013.500000  76.000000
# max    1017.000000  84.000000

# %%
df.dtypes

#object = string datatype
# Out:
# 0     int64
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7     int64
# dtype: object

# %%
df1.dtypes
# Out:
# id        int64
# name     object
# dob      object
# sex      object
# class    object
# hcode    object
# dcode    object
# mtest     int64
# dtype: object

# %%
#Storing data

# %%
#Index parameter: To remove unwanted row indexes in the first column we write index=False

df1.to_csv("student1.csv", index=False, header=False)

# %%
df1.to_csv("student1.csv", index=False, header=False, sep="#", columns=['Id','name','dob', 'sex', 'class', 'hcode'])

# %%
#Column and row seletion functions

# %%
#To get a list of all columns

df1.columns
# Out:
# Index(['id', 'name', 'dob', 'sex', 'class', 'hcode', 'dcode', 'mtest'], dtype='object')

# %%
#Interested in id column

#PANDAS has 2 types of records: Series is only 1 record and Dataframe 

type(df1['id']) #Series is equivalrnt to list in Pandas
# Out:
# pandas.core.series.Series

# %%
type(df1[['id']]) #Passing column name in a form of list, it will return Dataframe instead of series
# Out:
# pandas.core.frame.DataFrame

# %%
#Fetching 1 column at a time

df1[['id']]
# Out:
#      id
# 0  1001
# 1  1002
# 2  1003
# 3  1004
# 4  1005

# %%
#Fetching more than 1 column at a time

df1[['id', 'name', 'dob', 'sex', 'class']]
# Out:
#      id   name         dob sex class
# 0  1001    ABA   11/5/1986   M    1A
# 1  1002   Mary  25-06-1986   F    2B
# 2  1003  David  17-03-1988   M    1A
# 3  1004   John  17-01-1985   M    1C
# 4  1005    May  15-11-1986   F    1A

# %% [markdown]
# # Reading data from Excel sheet

# %%
#By default it will read the 1st sheet, inorder to make it read sheet of our choice we can provide sheetname


df2 = pd.read_excel(r"C:\Users\Lakshya\Downloads\LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx",sheet_name='Add your take on balances')

# %%
df2

#We can perform many operation same as csv by typing df2.(Press Tab)
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
#Reading data from html page

# %%
df4 = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
df4
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
#html page has multiple tables which will be read by pd.read_html and provide all these tables in the form of list

type(df4)
# Out:
# list

# %%
#To find total number of tables in a list 

len(df4)   #No of tables
# Out:
# 6

# %%
#To find the location of a table at different indexes

df4[0]      #1st table
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df4[1]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
# ...

# %%
df4[5]
# Out:
#        Season   Age   Tm   Lg  Pos      G      MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0   153.0  15.3  0.596  0.000  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   490.0  15.2  0.514  0.007  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   569.0  18.9  0.558  0.025  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   366.0  17.1  0.484  0.067  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   581.0  16.6  0.633  0.088  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   602.0  15.3  0.629  0.423  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   307.0  14.4  0.527  0.292  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0   260.0  10.9  0.533  0.333  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0   500.0  15.1  0.532  0.197  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0   251.0  25.2  0.702  0.409  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    18.0  30.7  0.644  0.333  ...
# ...

# %%
df4[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-33aee04df484> in <module>
# ----> 1 df4[6]
#
# IndexError: list index out of range

# %%
#Store data from html page in the form of csv inside our system


df4[3].to_csv("players_data.csv")

# %%
#To store all the tables at once by creating new csv files inside my directory

html_data = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool'")
for i in range(len(html_data)):
    html_data[i].to_csv(f"html_data{i}.csv", index=False)

# %%
#Pull data inside our system using Pandas, Reading data from github

pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Reading data in any other format

#For eg: This dataset is available as a string in the dict format

s = """{
"name" : "sudh",
"phone_no" : "745387456",
"company" : ["iNeuron", "EY", "Unilever", "Verizon", "Wipro"]
}
"""

# %%
#To load data in a json format: Key:value pairs kind of datastructure

"""JavaScript Object Notation (JSON) is a standard text-based format for 
representing structured data based on JavaScript object syntax. 
It is commonly used for transmitting data in web applications
(e.g., sending some data from the server to the client,
so it can be displayed on a web page, or vice versa)"""

import json

# %%
s1 = json.loads(s)

# %%
s1
# Out:
# {'name': 'sudh',
#  'phone_no': '745387456',
#  'company': ['iNeuron', 'EY', 'Unilever', 'Verizon', 'Wipro']}

# %%
#Conversion of json data into a data frame(tabular format)

pd.DataFrame(s1)
# Out:
#    name   phone_no   company
# 0  sudh  745387456   iNeuron
# 1  sudh  745387456        EY
# 2  sudh  745387456  Unilever
# 3  sudh  745387456   Verizon
# 4  sudh  745387456     Wipro

# %%
#To extract a particular column

pd.DataFrame(s1,columns=['company'])
# Out:
#     company
# 0   iNeuron
# 1        EY
# 2  Unilever
# 3   Verizon
# 4     Wipro

# %%
#Nested json

# %%
import requests  #same request we used to create inside flask

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js    #complex json loaded
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45175',
#   'id': 1092601251,
#   'node_id': 'PR_kwDOAA0YD84weM43',
#   'number': 45175,
#   'title': 'BUG: MultiIndex dtypes incorrect if level names not unique',
#   'user': {'login': 'johnzangwill',
#    'id': 8927258,
#    'node_id': 'MDQ6VXNlcjg5MjcyNTg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8927258?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/johnzangwill',
#    'html_url': 'https://github.com/johnzangwill',
# ...

# %%
type(js)
# Out:
# list

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45175/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/45175',
#  'id': 1092601251,
#  'node_id': 'PR_kwDOAA0YD84weM43',
#  'number': 45175,
#  'title': 'BUG: MultiIndex dtypes incorrect if level names not unique',
#  'user': {'login': 'johnzangwill',
#   'id': 8927258,
#   'node_id': 'MDQ6VXNlcjg5MjcyNTg=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8927258?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/johnzangwill',
#   'html_url': 'https://github.com/johnzangwill',
# ...

# %%
#Q- Give me all the titles we hae in this data, first we have to convert data into a tabular format

js[0]["title"]
# Out:
# 'BUG: MultiIndex dtypes incorrect if level names not unique'

# %%
#a) Give me all the titles

for i in range(len(js)):
    print(js[i]["title"])
# Out:
# BUG: MultiIndex dtypes incorrect if level names not unique
# BUG: MultiIndex dtypes incorrect if level names not unique
# STYLE add vulture hook
# allow multiple series argument calling in ufunc
# PERF: expanding/rolling.min/max with engine='numba'
# ASV: Add merge on categorical benchmarks
# API: Allow other na values in StringArray Constructor
# TST: tests for nullable issues
# REF: separate numpy-specific part of can_hold_element
# TST: Clean pg8000 test
# TST: Parameterize
# API: series_with_int64index[i:j] should be label-based
# BUG: clip raising with na series bounds for datetimes or ea int
# BUG: DataFrameGroupBy.value_counts() fails if as_index=False and there are duplicate column labels
# BUG: pd._libs.lib.is_iterator reports Timestamp as iterable on Cygwin
# BUG: `Styler.apply_index` fails with LaTeX conversion with hidden Multi levels
# BUG: latex styling index and hide levels
# TST: tests for setitem-like casting issues
# ...

# %%
#b Convert data into a tabular format, choosing columns of your choice(url, title in this example)

pd.DataFrame(js,columns=['url','title'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df4 = pd.DataFrame(js).head()

# %%
df4
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
#To store json converted dataframe df4 into a csv file in our system

df4.to_csv('json_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'johnzangwill',
#  'id': 8927258,
#  'node_id': 'MDQ6VXNlcjg5MjcyNTg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8927258?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/johnzangwill',
#  'html_url': 'https://github.com/johnzangwill',
#  'followers_url': 'https://api.github.com/users/johnzangwill/followers',
#  'following_url': 'https://api.github.com/users/johnzangwill/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/johnzangwill/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/johnzangwill/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/johnzangwill/subscriptions',
#  'organizations_url': 'https://api.github.com/users/johnzangwill/orgs',
#  'repos_url': 'https://api.github.com/users/johnzangwill/repos',
#  'events_url': 'https://api.github.com/users/johnzangwill/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/johnzangwill/received_events',
# ...

# %%
df5 = pd.DataFrame([js[i]['user'] for i in range(len(js))])

# %%
df5
# Out:
#            login        id               node_id  \
# 0   johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 1   johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 2   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 3        miettal    118803  MDQ6VXNlcjExODgwMw==
# 4      mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5     lukemanley   8519523  MDQ6VXNlcjg1MTk1MjM=
# 6      lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 7   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9      mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10     mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 11  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 12         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13  johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 14         DWesl  22566757  MDQ6VXNlcjIyNTY2NzU3
# 15      attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 16      attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 17  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# ...

# %%
pd.DataFrame([js[0]['user']])
# Out:
#           login       id               node_id  \
# 0  johnzangwill  8927258  MDQ6VXNlcjg5MjcyNTg=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/892725...
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/johnzangwill  https://github.com/johnzangwill
#
#                                        followers_url  \
# 0  https://api.github.com/users/johnzangwill/foll...
#
#                                        following_url  \
# 0  https://api.github.com/users/johnzangwill/foll...
#
#                                            gists_url  \
# 0  https://api.github.com/users/johnzangwill/gist...
#
#                                          starred_url  \
# 0  https://api.github.com/users/johnzangwill/star...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/johnzangwill/subs...
#
# ...

# %%
lis=[]
for i in range(len(js)):    #To find total no of dictionaries we have
    lis.append(js[i]["user"]) #We will go inside every dict and try to extract user data
pd.DataFrame(lis)   #We will append the data extracted into a list
# Out:
#            login        id               node_id  \
# 0   johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 1   johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 2   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 3        miettal    118803  MDQ6VXNlcjExODgwMw==
# 4      mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 5     lukemanley   8519523  MDQ6VXNlcjg1MTk1MjM=
# 6      lithomas1  47963215  MDQ6VXNlcjQ3OTYzMjE1
# 7   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 9      mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 10     mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 11  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 12         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13  johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 14         DWesl  22566757  MDQ6VXNlcjIyNTY2NzU3
# 15      attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 16      attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 17  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# ...

# %%
#Different approach using from_records function

json_data= pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user']) #Automatically it will be able to parse data and unravel
data.head()
# Out:
#           login        id               node_id  \
# 0      attack68  24256554  MDQ6VXNlcjI0MjU2NTU0
# 1  johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 2  johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# 3  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 4       miettal    118803  MDQ6VXNlcjExODgwMw==
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/242565...
# 1  https://avatars.githubusercontent.com/u/892725...
# 2  https://avatars.githubusercontent.com/u/892725...
# 3  https://avatars.githubusercontent.com/u/334916...
# 4  https://avatars.githubusercontent.com/u/118803...
#
#                                          url                         html_url  \
# 0      https://api.github.com/users/attack68      https://github.com/attack68
# 1  https://api.github.com/users/johnzangwill  https://github.com/johnzangwill
# 2  https://api.github.com/users/johnzangwill  https://github.com/johnzangwill
# ...

# %%
html_data = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool'")
for i in range(len(html_data)):
    html_data[i].to_csv(f"html_data{i}.csv", index=False)

# %%
import pandas as pd

# %%
#Loadind csv files

form_file = pd.read_csv("html_data1.csv")

# %%
#Storing file in the pickle formatj

form_file.to_pickle("my_pickle")   #Binary file format

# %%
pwd()
# Out:
# 'C:\\Users\\Lakshya\\DS_Python'

# %%
#.h5 file format


h5_data = pd.HDFStore('test.h5')   #h5 file object

# %%
h5_data['obj1'] = form_file  #Civilised form of data
# Out:
# C:\Users\Lakshya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Season', 'Tm', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_data["obj1"]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
# ...

# %%
h5_data.put('obj2', form_file, format='table')

# %%
h5_data.select('obj2', where = ['index >= 10 and index <=15'])
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG  FGA  ...    FT%  \
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5  3.0  ...  1.000
# 11     Career   NaN  NaN  NBA  NaN  146.0  102.0  28.1  4.5  8.9  ...  0.792
# 12        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  NaN  ...    NaN
# 13  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  8.8  ...  0.768
# 14  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  24.0  4.5  9.2  ...  0.824
# 15   1 season   NaN  LAC  NBA  NaN    2.0    0.0   9.0  1.5  3.0  ...  1.000
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 10  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
# 11  1.9  4.7  6.5  0.7  0.4  2.0  1.0  3.1  11.0
# 12  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13  2.2  4.5  6.7  0.5  0.5  2.5  0.8  3.2  10.9
# 14  1.3  5.1  6.4  1.1  0.3  1.2  1.2  3.0  11.2
# 15  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
#
# [6 rows x 30 columns]

# %%
 #Serde= Serialization(Writing data), Deserialization(Reading/Selecting data)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes == 'object'   #Filteration operation
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']  #series
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df1 = df[df.dtypes[df.dtypes == 'object'].index]

# %%
df1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1.describe()
# Out:
#                        Name   Sex Ticket    Cabin Embarked
# count                   891   891    891      204      889
# unique                  891     2    681      147        3
# top     Mernagh, Mr. Robert  male   1601  B96 B98        S
# freq                      1   577      7        4      644

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=='float64'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'float64']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
type(df.dtypes[df.dtypes == 'float64'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'float64'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
df[["Name", 'Fare']]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 886                              Montvila, Rev. Juozas  13.0000
# 887                       Graham, Miss. Margaret Edith  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889                              Behr, Mr. Karl Howell  30.0000
# 890                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 2 columns]

# %%
[df.dtypes[df.dtypes == 'float64'].index]
# Out:
# [Index(['Age', 'Fare'], dtype='object')]

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df["Name"][5:10]
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df["Name"][5:10:2]
# Out:
# 5                       Moran, Mr. James
# 7         Palsson, Master. Gosta Leonard
# 9    Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df["Ticket"][5:16]
# Out:
# 5        330877
# 6         17463
# 7        349909
# 8        347742
# 9        237736
# 10      PP 9549
# 11       113783
# 12    A/5. 2151
# 13       347082
# 14       350406
# 15       248706
# Name: Ticket, dtype: object

# %%
df[["Ticket"]][5:16]
# Out:
#        Ticket
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
sorted(df["Ticket"])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
for i in df.columns:
    print(df[i])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Adding a new column in a dataframe

# %%
df['sudh']= 'kumar'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['sudh'] = df['PassengerId']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df['Cabin'])  #In-built function to give direct categories of data
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Pclass'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
df['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
ser = df['Cabin'][df['Cabin'].isnull() == False]

# %%
ser
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
ser.index
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
df.iloc[ser.index]   #Row wiseselection
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[[1,6,5,4,7]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 6            7         0       1
# 5            6         0       3
# 4            5         0       3
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 4                           Allen, Mr. William Henry    male  35.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch    Ticket     Fare Cabin Embarked  sudh
# 1      0  PC 17599  71.2833   C85        C     2
# 6      0     17463  51.8625   E46        S     7
# 5      0    330877   8.4583   NaN        Q     6
# 4      0    373450   8.0500   NaN        S     5
# 7      1    349909  21.0750   NaN        S     8

# %%
df['Fare'] == max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df['new_col'] = df['PassengerId'] + df['Age']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task
